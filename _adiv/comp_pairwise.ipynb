# %% [markdown]
# # Pairwise plot for frequency per sample
# Pairwise plots (comparable to ggpairs in ggally) for sequence counts per method with ranked samples colored by variable
# only problem now is need to be able to add which variable you want to use for coloring the fig

# %%
#var needs to be fixed and vars in sns pairplot

def merge_df(filenames, metadata=None, var=None):
    smpl = pd.merge(pd.read_csv(filenames[1]), pd.read_csv(filenames[2]), on = 'sample')
    for i in range(len(filenames)-1):
        smpl = pd.merge(smpl, pd.read_csv(filenames[i+2]), on = 'sample')
        if metadata:
            smpl.rename(columns={'sample':'sample-id'}, inplace=True)
            smpl = pd.merge(smpl,pd.read_csv(metadata), on = 'sample-id')
            if var:
                sns.pairplot(smpl, hue = 'var')
            else: return 'Variable must be provided if metadata'
        else: return sns.pairplot(smpl)
    return

# %%
#this what you should be able to give as an input
merge_df(files, meta, depth_code)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-a585f77ac2ce> in <module>
# ----> 1 merge_df(files, meta, depth_code)
#
# NameError: name 'depth_code' is not defined

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
files = ['~/Documents/didi/s2.csv','/home/diane/Documents/didi/s11.csv']
meta = '/home/diane/Documents/didi/METADATA.csv'

# %%
files = ['~/data/csv files/s2.csv','/Users/Diana/data/csv files/s27.csv','~/data/csv files/s97-2.csv']
meta = '/Users/Diana/data/metadata/METADATA.csv'

# %%
def pairplt (filenames, metadata=None):
    smpl = pd.merge(pd.read_csv(filenames[1]), pd.read_csv(filenames[2]), on = 'sample')
    for i in range(len(filenames)-1):
        smpl = pd.merge(smpl, pd.read_csv(filenames[i+2]), on = 'sample')
        if metadata:
            smpl.rename(columns={'sample':'sample-id'}, inplace=True)
            smpl = pd.merge(smpl,pd.read_csv(metadata), on = 'sample-id')
            sns.pairplot(smpl, hue = 'depth_code', vars = ['f2','f27','f97-2'])
    else: return sns.pairplot(smpl, vars = ['f2','f27','f97-2'])
    return

# %%
pairplt( files, meta )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'f2'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-4c59bdedcf35> in <module>
# ----> 1 pairplt( files, meta )
#
# <ipython-input-12-b874106fb808> in pairplt(filenames, metadata)
#       6             smpl.rename(columns={'sample':'sample-id'}, inplace=True)
#       7             smpl = pd.merge(smpl,pd.read_csv(metadata), on = 'sample-id')
# ----> 8             sns.pairplot(smpl, hue = 'depth_code', vars = ['f2','f27','f97-2'])
#       9     else: return sns.pairplot(smpl, vars = ['f2','f27','f97-2'])
#      10     return
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2109             diag_kws.setdefault("shade", True)
#    2110             diag_kws["legend"] = False
# -> 2111             grid.map_diag(kdeplot, **diag_kws)
#    2112
#    2113     # Maybe plot on the off-diagonals
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in map_diag(self, func, **kwargs)
#    1380         for i, var in enumerate(self.x_vars):
#    1381             ax = self.diag_axes[i]
# -> 1382             hue_grouped = self.data[var].groupby(self.hue_vals)
#    1383
#    1384             plt.sca(ax)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'f2'

# %%
smpl = pd.merge(pd.read_csv('~/data/csv files/s2.csv'), pd.read_csv('/Users/Diana/data/csv files/s27.csv'), on = 'sample')

# %%
smpl = pd.merge(smpl, pd.read_csv('/Users/Diana/data/csv files/s97-2.csv'), on = 'sample')

# %%
smpl.rename(columns={'sample':'sample-id',
                    'f2':'DADA2',
                    'f27':'Deblur',
                    'f97-2':'OTU97'}, inplace=True)
smpl = pd.melt(smpl, id_vars='sample-id')
smpl = pd.merge(smpl,pd.read_csv(meta), on = 'sample-id')

# %%
import ptitprince as pt

# %%
smpl = pd.melt(smpl, id_vars='sample-id')

# %%
smpl
# Out:
#           sample-id variable  value         investigation_id    date  week  \
# 0    16SV6-BB16.19D    DADA2  11150  BedfordBasin_TimeSeries  11-May    19
# 1    16SV6-BB16.19D   Deblur  15519  BedfordBasin_TimeSeries  11-May    19
# 2    16SV6-BB16.19D    OTU97  20939  BedfordBasin_TimeSeries  11-May    19
# 3    16SV6-BB16.38A    DADA2  10552  BedfordBasin_TimeSeries  21-Sep    38
# 4    16SV6-BB16.38A   Deblur   6343  BedfordBasin_TimeSeries  21-Sep    38
# 5    16SV6-BB16.38A    OTU97  12658  BedfordBasin_TimeSeries  21-Sep    38
# 6    16SV6-BB16.27D    DADA2  10313  BedfordBasin_TimeSeries  06-Jul    27
# 7    16SV6-BB16.27D   Deblur  15522  BedfordBasin_TimeSeries  06-Jul    27
# 8    16SV6-BB16.27D    OTU97  20368  BedfordBasin_TimeSeries  06-Jul    27
# 9    16SV6-BB16.28D    DADA2  10109  BedfordBasin_TimeSeries  13-Jul    28
# 10   16SV6-BB16.28D   Deblur  14385  BedfordBasin_TimeSeries  13-Jul    28
# 11   16SV6-BB16.28D    OTU97  19298  BedfordBasin_TimeSeries  13-Jul    28
# 12   16SV6-BB16.04A    DADA2   9956  BedfordBasin_TimeSeries  27-Jan     4
# 13   16SV6-BB16.04A   Deblur   6200  BedfordBasin_TimeSeries  27-Jan     4
# 14   16SV6-BB16.04A    OTU97  11358  BedfordBasin_TimeSeries  27-Jan     4
# 15   16SV6-BB16.44A    DADA2   9818  BedfordBasin_TimeSeries  02-Nov    44
# 16   16SV6-BB16.44A   Deblur   5628  BedfordBasin_TimeSeries  02-Nov    44
# 17   16SV6-BB16.44A    OTU97  11043  BedfordBasin_TimeSeries  02-Nov    44
# 18   16SV6-BB16.21C    DADA2   9782  BedfordBasin_TimeSeries  25-May    21
# 19   16SV6-BB16.21C   Deblur  16768  BedfordBasin_TimeSeries  25-May    21
# 20   16SV6-BB16.21C    OTU97  22148  BedfordBasin_TimeSeries  25-May    21
# 21    16SV6-BB16.7D    DADA2   9567  BedfordBasin_TimeSeries  17-Feb     7
# 22    16SV6-BB16.7D   Deblur  14300  BedfordBasin_TimeSeries  17-Feb     7
# 23    16SV6-BB16.7D    OTU97  19591  BedfordBasin_TimeSeries  17-Feb     7
# 24    16SV6-BB16.9D    DADA2   9505  BedfordBasin_TimeSeries  02-Mar     9
# 25    16SV6-BB16.9D   Deblur  15743  BedfordBasin_TimeSeries  02-Mar     9
# 26    16SV6-BB16.9D    OTU97  21551  BedfordBasin_TimeSeries  02-Mar     9
# 27   16SV6-BB16.22D    DADA2   9348  BedfordBasin_TimeSeries  01-Jun    22
# 28   16SV6-BB16.22D   Deblur  14654  BedfordBasin_TimeSeries  01-Jun    22
# 29   16SV6-BB16.22D    OTU97  20403  BedfordBasin_TimeSeries  01-Jun    22
# ..              ...      ...    ...                      ...     ...   ...
# 570  16SV6-BB16.38C    DADA2   2662  BedfordBasin_TimeSeries  21-Sep    38
# 571  16SV6-BB16.38C   Deblur   5969  BedfordBasin_TimeSeries  21-Sep    38
# 572  16SV6-BB16.38C    OTU97   6769  BedfordBasin_TimeSeries  21-Sep    38
# 573  16SV6-BB16.40B    DADA2   2654  BedfordBasin_TimeSeries  05-Oct    40
# 574  16SV6-BB16.40B   Deblur   5098  BedfordBasin_TimeSeries  05-Oct    40
# 575  16SV6-BB16.40B    OTU97   5645  BedfordBasin_TimeSeries  05-Oct    40
# 576  16SV6-BB16.42C    DADA2   2388  BedfordBasin_TimeSeries  19-Oct    42
# 577  16SV6-BB16.42C   Deblur   3703  BedfordBasin_TimeSeries  19-Oct    42
# 578  16SV6-BB16.42C    OTU97   3801  BedfordBasin_TimeSeries  19-Oct    42
# 579  16SV6-BB16.40C    DADA2   2256  BedfordBasin_TimeSeries  05-Oct    40
# 580  16SV6-BB16.40C   Deblur   4233  BedfordBasin_TimeSeries  05-Oct    40
# 581  16SV6-BB16.40C    OTU97   4820  BedfordBasin_TimeSeries  05-Oct    40
# 582  16SV6-BB16.41B    DADA2   1879  BedfordBasin_TimeSeries  12-Oct    41
# 583  16SV6-BB16.41B   Deblur   2853  BedfordBasin_TimeSeries  12-Oct    41
# 584  16SV6-BB16.41B    OTU97   3295  BedfordBasin_TimeSeries  12-Oct    41
# 585  16SV6-BB16.39B    DADA2   1444  BedfordBasin_TimeSeries  28-Sep    39
# 586  16SV6-BB16.39B   Deblur   2842  BedfordBasin_TimeSeries  28-Sep    39
# 587  16SV6-BB16.39B    OTU97   3173  BedfordBasin_TimeSeries  28-Sep    39
# 588  16SV6-BB16.41C    DADA2   1425  BedfordBasin_TimeSeries  12-Oct    41
# 589  16SV6-BB16.41C   Deblur   2570  BedfordBasin_TimeSeries  12-Oct    41
# 590  16SV6-BB16.41C    OTU97   3041  BedfordBasin_TimeSeries  12-Oct    41
# 591  16SV6-BB16.39C    DADA2   1401  BedfordBasin_TimeSeries  28-Sep    39
# 592  16SV6-BB16.39C   Deblur   2921  BedfordBasin_TimeSeries  28-Sep    39
# 593  16SV6-BB16.39C    OTU97   3108  BedfordBasin_TimeSeries  28-Sep    39
# 594  16SV6-BB16.42B    DADA2   1000  BedfordBasin_TimeSeries  19-Oct    42
# 595  16SV6-BB16.42B   Deblur   1884  BedfordBasin_TimeSeries  19-Oct    42
# 596  16SV6-BB16.42B    OTU97   1612  BedfordBasin_TimeSeries  19-Oct    42
# 597  16SV6-BB16.42D    DADA2    271  BedfordBasin_TimeSeries  19-Oct    42
# 598  16SV6-BB16.42D   Deblur    982  BedfordBasin_TimeSeries  19-Oct    42
# 599  16SV6-BB16.42D    OTU97    350  BedfordBasin_TimeSeries  19-Oct    42
#
#      week_plus_year  depth depth_code      name month
# 0                70     60          D  BB16.19D   May
# 1                70     60          D  BB16.19D   May
# 2                70     60          D  BB16.19D   May
# 3                89      1          A  BB16.38A   Sep
# 4                89      1          A  BB16.38A   Sep
# 5                89      1          A  BB16.38A   Sep
# 6                78     60          D  BB16.27D   Jul
# 7                78     60          D  BB16.27D   Jul
# 8                78     60          D  BB16.27D   Jul
# 9                79     60          D  BB16.28D   Jul
# 10               79     60          D  BB16.28D   Jul
# 11               79     60          D  BB16.28D   Jul
# 12               55      1          A   BB16.4A   Jan
# 13               55      1          A   BB16.4A   Jan
# 14               55      1          A   BB16.4A   Jan
# 15               95      1          A  BB16.44A   Nov
# 16               95      1          A  BB16.44A   Nov
# 17               95      1          A  BB16.44A   Nov
# 18               72     10          C  BB16.21C   May
# 19               72     10          C  BB16.21C   May
# 20               72     10          C  BB16.21C   May
# 21               58     60          D   BB16.7D   Feb
# 22               58     60          D   BB16.7D   Feb
# 23               58     60          D   BB16.7D   Feb
# 24               60     60          D   BB16.9D   Mar
# 25               60     60          D   BB16.9D   Mar
# 26               60     60          D   BB16.9D   Mar
# 27               73     60          D  BB16.22D   Jun
# 28               73     60          D  BB16.22D   Jun
# 29               73     60          D  BB16.22D   Jun
# ..              ...    ...        ...       ...   ...
# 570              89     10          C  BB16.38C   Sep
# 571              89     10          C  BB16.38C   Sep
# 572              89     10          C  BB16.38C   Sep
# 573              91      5          B  BB16.40B   Oct
# 574              91      5          B  BB16.40B   Oct
# 575              91      5          B  BB16.40B   Oct
# 576              93     10          C  BB16.42C   Oct
# 577              93     10          C  BB16.42C   Oct
# 578              93     10          C  BB16.42C   Oct
# 579              91     10          C  BB16.40C   Oct
# 580              91     10          C  BB16.40C   Oct
# 581              91     10          C  BB16.40C   Oct
# 582              92      5          B  BB16.41B   Oct
# 583              92      5          B  BB16.41B   Oct
# 584              92      5          B  BB16.41B   Oct
# 585              90      5          B  BB16.39B   Sep
# 586              90      5          B  BB16.39B   Sep
# 587              90      5          B  BB16.39B   Sep
# 588              92     10          C  BB16.41C   Oct
# 589              92     10          C  BB16.41C   Oct
# 590              92     10          C  BB16.41C   Oct
# 591              90     10          C  BB16.39C   Sep
# 592              90     10          C  BB16.39C   Sep
# 593              90     10          C  BB16.39C   Sep
# 594              93      5          B  BB16.42B   Oct
# 595              93      5          B  BB16.42B   Oct
# 596              93      5          B  BB16.42B   Oct
# 597              93     60          D  BB16.42D   Oct
# 598              93     60          D  BB16.42D   Oct
# 599              93     60          D  BB16.42D   Oct
#
# [600 rows x 11 columns]

# %%
rcp = pt.RainCloud(x = 'variable', y = 'value',
                 data = smpl, orient = 'h',
                 hue = 'depth_code', alpha=0.65)

# %%
sns.pairplot(smpl, hue = 'depth', vars = ['DADA2','Deblur','OTU97'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-86f9d08bf0ed> in <module>
# ----> 1 sns.pairplot(smpl, hue = 'depth', vars = ['DADA2','Deblur','OTU97'])
#
# NameError: name 'sns' is not defined
